# %%
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt


P = [4*np.sin(19*np.pi*t) for t in np.linspace(0,1, 1000)]

R = [5*np.sin(15*np.pi*t) for t in np.linspace(0,3, 1000)]

A = [9*np.sin(9*np.pi*t) for t in np.linspace(0,4, 1000)]

output=[i+J+K for i,J,K in zip(P,R,A)]

plt.plot(output)

Pra=np.fft.fft(output)
plt.plot(output)
print(output)
plt.plot(Pra)
plt.plot(Pra)
plt.show()
# Out:
# [0.0, 1.9607843620190915, 3.893600329146997, 5.770931078530385, 7.56615515146577, 9.253974825681802, 10.810821705329724, 12.215232575925999, 13.448189105851736, 14.493415625108513, 15.33762996381801, 15.970743173499304, 16.386004867900315, 16.580091890203537, 16.553139021863245, 16.308711476580118, 15.853719952076592, 15.198280023532755, 14.355518637299811, 13.341331384084066, 12.174095080517189, 10.874340951607612, 9.464394370376692, 7.967987663312824, 6.409852921548039, 4.8153020605991745, 3.209801541276981, 1.6185491986200968, 0.06606052467389073, -1.424228482647067, -2.830335153286614, -4.132074390713683, -5.311367649546934, -6.352511654050308, -7.242402639993124, -7.970712745596582, -8.530016073921908, -8.915862881961965, -9.126801303190511, -9.164346962499405, -9.032901777539951, -8.739624141174545, -8.294253529528593, -7.708893363607373, -6.997756655598643, -6.176879581463421, -5.263808628747333, -4.277267364310022, -3.2368091446712226, -2.162462248020357, -1.0743739401164758,
# ...

# %%
import numpy as n
from scipy import signal
import random as r
import matplotlib.pyplot as plt
sig = [5*n.sin(2*n.pi*t) for t in n.linspace(0,1,1000)]
noise = [r.random()-0.5 for i in n.linspace(0,1,1000)]
xn = [i+j for i,j in zip(sig,noise)]
m=100
l=m-1/m
xnn=list(n.zeros(m-1))+list(xn)
#w, h = signal.freqs(out)
yn = [l*sum(xnn[k-m+1:k])+(1-l)*xnn[k] for k in n.arange(m-1,len(xnn))]
plt.semilogx(w, 20 * n.log10(abs(h)))
plt.title('Butterworth filter frequency response')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
plt.axvline(100, color='green')
#plt.plot(xn)
plt.plot(yn,color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a466ffcaaee0> in <module>
#      11 #w, h = signal.freqs(out)
#      12 yn = [l*sum(xnn[k-m+1:k])+(1-l)*xnn[k] for k in n.arange(m-1,len(xnn))]
# ---> 13 plt.semilogx(w, 20 * n.log10(abs(h)))
#      14 plt.title('Butterworth filter frequency response')
#      15 plt.xlabel('Frequency [radians / second]')
#
# NameError: name 'w' is not defined
